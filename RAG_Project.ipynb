# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0b52518f-3644-448d-9cee-db5170126323" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b52518f-3644-448d-9cee-db5170126323">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d haithemhermessi/sanad-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/haithemhermessi/sanad-dataset
# License(s): U.S. Government Works
# ...
#  72% 47.0M/65.7M [00:00<00:00, 252MB/s]
# 100% 65.7M/65.7M [00:00<00:00, 268MB/s]

# %%
import zipfile
with zipfile.ZipFile('/content/sanad-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('Sanad')

# %%
import os
from tqdm import tqdm
import os
import glob

# %%
data_dir = '/content/Sanad'
folders = os.listdir(data_dir)

texts = []

for folder in tqdm(folders, desc="Processing Folders"):
        folder_path = os.path.join(data_dir, folder)
        if os.path.isdir(folder_path):
            files = glob.glob(f"{folder_path}/*.txt")
            for file in tqdm(files, desc=f"Processing Files in {folder}", leave=False):
                with open(file, 'r', encoding='utf-8') as f:
                    content = f.read().strip()
                    texts.append(content)

print(f"Loaded {len(texts)} documents.")
# Out:
# ...
# Processing Folders: 100%|██████████| 7/7 [00:02<00:00,  3.48it/s]
# Loaded 45500 documents.

# %%
print(f"Loaded {len(texts)} documents.")
# Out:
# Loaded 45500 documents.

# %%
# !pip install langchain_chroma
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 34.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 25.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 82.8 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain
# !pip install langchain_google_genai
from sentence_transformers import SentenceTransformer
from langchain_chroma import Chroma
from sentence_transformers import SentenceTransformer
import torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.3 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class embedding:
    def __init__(self):
        self.model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2').to(device)

    def embed_documents(self, docs):
        embeddings = self.model.encode(docs, convert_to_tensor=True, device=device)
        return embeddings.cpu().numpy().tolist()

    def embed_query(self, query):
        embeddings = self.model.encode(query, convert_to_tensor=True, device=device)
        return embeddings.cpu().numpy().tolist()

embed_model = embedding()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.12k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# ...

# %%
def batchــ(texts, batch_size, embed_model):
    vector_database = None
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        embeddings = embed_model.embed_documents(batch_texts)  # Embeddings on GPU

        if vector_database is None:
            vector_database = Chroma.from_texts(
                texts=batch_texts,
                embedding=embed_model,
                metadatas=None,
                ids=None,
                persist_directory='chroma_db'
            )
        else:
            vector_database.add_texts(
                texts=batch_texts,
                embeddings=embeddings,
                persist_directory='chroma_db'
            )
    return vector_database

# Set the batch size
batch_size = 20000
vector_database = batchــ(texts, batch_size, embed_model)

retreiver = vector_database.as_retriever(search_type='similarity', search_kwargs={'k': 3})

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

context_chain = retreiver | format_docs

# %%
GOOGLE_API_KEY = "AIzaSyDUbM4d5dN8fXevXjT4L5oRmv3i2r7ZvR0"

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import PromptTemplate


llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash",google_api_key =GOOGLE_API_KEY ,temperature=0)

template = """
As a knowledgeable and context-aware Arabic AI assistant,
your role is to deliver accurate and thorough responses to customer inquiries.
Utilize the retrieved information from the knowledge base to craft a well-informed answer.

Question: {question}

Relevant Information:
{context}

Generate a clear and precise Arabic response using the provided context.
"""

prompt=PromptTemplate.from_template(template)

# %%
rag_chain = (
     {"context": context_chain,"question": RunnablePassthrough()}
     | prompt
     | llm
     |StrOutputParser()
)

# %%
def retrieve_articles(question):
    articles = [
        retreiver.invoke(question)[0].page_content,
        retreiver.invoke(question)[1].page_content,
        retreiver.invoke(question)[2].page_content
    ]
    return articles

def get_answer(question):
    answer = rag_chain.invoke(question)
    return answer

def process_question(question):
    articles = retrieve_articles(question)
    answer = get_answer(question)
    return articles, answer



ans=process_question('ما هي العوامل التي ساهمت في تفوق أداء شركات الإمارات في مؤشر ستاندرد أند بورز؟')

print('Answer to the Question :',ans[1])
# Out:
# Answer to the Question : ساهمت العديد من العوامل في تفوق أداء شركات الإمارات في مؤشر ستاندرد أند بورز، من أهمها:
#
# * **النمو الاقتصادي القوي:** تتمتع الإمارات باقتصاد قوي ومتنوع، مما أدى إلى نمو شركاتها بشكل ملحوظ.
# * **الاستثمارات الكبيرة:**  تستثمر الإمارات بكثافة في البنية التحتية والمشاريع الخدمية، مما يدعم نمو الشركات.
# * **السيولة العالية:**  تتمتع الإمارات بسيولة عالية، مما يسهل على الشركات الحصول على التمويل اللازم للنمو.
# * **الاستقرار السياسي:**  تتمتع الإمارات بالاستقرار السياسي، مما يوفر بيئة مواتية للاستثمار.
# * **إدراج الشركات الإماراتية في مؤشر فوتسي:**  ساهم إدراج عدد كبير من الشركات الإماراتية في مؤشر فوتسي في تعزيز ثقة المستثمرين الأجانب في السوق الإماراتية.
# * **اتفاق دبي العالمية والدائنين:**  أشاع الاتفاق بين دبي العالمية ودائنيها الثقة في قدرة الإمارات على سداد ديونها، مما عزز ثقة المستثمرين.
# * **تنويع الاقتصاد:**  نجحت الإمارات في تنويع اقتصادها، مما قلل من اعتمادها على قطاع واحد، مما أدى إلى زيادة استقرارها الاقتصادي.
# ...

# %%
print(('ُTop 3 Similar Articles : '))
print('Article 1 :',ans[0][0])
print('Article 2 :',ans[0][1])
print('Article 3 :',ans[0][2])
# Out:
# ُTop 3 Similar Articles :
# Article 1 : دبي عبير أبو شمالة: قال تيم إدواردز مدير الاستراتيجيات الاستثمارية لدى مؤشرات «ستاندرد أند بورز داو جونز» إن تحليلات الأداء لأسواق منطقة الشرق لأوسط في شهر يونيو الماضي، أظهرت أن الإمارات كانت من الأفضل أداءً ضمن مؤشر ستاندرد أند بورز «جي سي سي 40» للشركات من دول مجلس التعاون. ولفت في بيان أرسل نسخة منه ل«الخليج» إلى أنه وفي الوقت الذي تراجعت فيه الأسواق العالمية في الشهر الماضي، فإن مؤشر دول مجلس التعاون، والذي يقيس أداء أكبر 40 شركة في المنطقة، وأكثرها سيولة، تفوق في الأداء، وسجل نمواً بنسبة 2.5%.وقال إن شركات الإمارات كانت الأفضل أداءً بمكاسب وصلت إلى 2.9%. من جهة أخرى لفت البيان إلى التراجع في أداء المؤشرات العالمية على خلفية الأوضاع المالية والاقتصادية في اليونان والصين.
# ...

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 21.9 MB/s eta 0:00:00
# ...

# %%
# !pip install googledriver

# %%
from googledriver import download_folder

URL = "https://drive.google.com/drive/folders/1w7hUiuMAPZbMCMG_jGCfED88VmGoh2Pi?usp=sharing"

download_folder(URL, "/content/chroma_db")
# Out:
# ['/content/ITI/SQL/Day1/ERD1.png',
#  '/content/ITI/SQL/Day1/ERD2.png',
#  '/content/ITI/SQL/Day2/Day2.sql',
#  '/content/ITI/SQL/Day3/Data_Manipulating_Language.sql',
#  '/content/ITI/SQL/Day4/Day4.sql']

# %%
pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 35.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.5 MB/s eta 0:00:00
# ...

# %%
from langchain.vectorstores import Chroma

# Load the Chroma vector database
vector_database_test = Chroma(
    embedding_function=embed_model,
    persist_directory='chroma_db'
)
# Out:
# <ipython-input-41-ca862ad5e1e4>:4: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the langchain-chroma package and should be used instead. To use it run `pip install -U langchain-chroma` and import as `from langchain_chroma import Chroma`.
#   vector_database_test = Chroma(

# %%
retreiver_test = vector_database_test.as_retriever(search_type='similarity', search_kwargs={'k': 3})

# %%
def retrieve_articles(question):
    articles = [
        retreiver_test.invoke(question)[0].page_content,
        retreiver_test.invoke(question)[1].page_content,
        retreiver_test.invoke(question)[2].page_content
    ]
    return articles

def get_answer(question):
    answer = rag_chain.invoke(question)
    return answer

def process_question(question):
    articles = retrieve_articles(question)
    answer = get_answer(question)
    return articles, answer



ans=process_question('ما هي العوامل التي ساهمت في تفوق أداء شركات الإمارات في مؤشر ستاندرد أند بورز؟')

print('Answer to the Question :',ans[1])
# Out:
# Answer to the Question : ساهمت العديد من العوامل في تفوق أداء شركات الإمارات في مؤشر ستاندرد أند بورز، من أهمها:
#
# * **النمو الاقتصادي القوي:** تتمتع الإمارات باقتصاد قوي ومتنوع، مما أدى إلى نمو شركاتها بشكل ملحوظ.
# * **الاستثمارات الكبيرة:**  تستثمر الإمارات بكثافة في البنية التحتية والمشاريع الخدمية، مما يدعم نمو الشركات.
# * **السيولة العالية:**  تتمتع الإمارات بسيولة عالية، مما يسهل على الشركات الحصول على التمويل اللازم للنمو.
# * **الاستقرار السياسي:**  تتمتع الإمارات بالاستقرار السياسي، مما يوفر بيئة مواتية للاستثمار.
# * **إدراج الشركات الإماراتية في مؤشر فوتسي:**  ساهم إدراج عدد كبير من الشركات الإماراتية في مؤشر فوتسي في تعزيز ثقة المستثمرين الأجانب في السوق الإماراتية.
# * **اتفاق دبي العالمية والدائنين:**  أشاع الاتفاق بين دبي العالمية ودائنيها الثقة في قدرة الإمارات على سداد ديونها، مما عزز ثقة المستثمرين.
# * **تنويع الاقتصاد:**  نجحت الإمارات في تنويع اقتصادها، مما قلل من اعتمادها على قطاع واحد، مما أدى إلى زيادة استقرارها الاقتصادي.
# ...

# %%
print(('ُTop 3 Similar Articles : '))
print('Article 1 :',ans[0][0])
print('Article 2 :',ans[0][1])
print('Article 3 :',ans[0][2])
# Out:
# ُTop 3 Similar Articles :
# Article 1 : دبي عبير أبو شمالة: قال تيم إدواردز مدير الاستراتيجيات الاستثمارية لدى مؤشرات «ستاندرد أند بورز داو جونز» إن تحليلات الأداء لأسواق منطقة الشرق لأوسط في شهر يونيو الماضي، أظهرت أن الإمارات كانت من الأفضل أداءً ضمن مؤشر ستاندرد أند بورز «جي سي سي 40» للشركات من دول مجلس التعاون. ولفت في بيان أرسل نسخة منه ل«الخليج» إلى أنه وفي الوقت الذي تراجعت فيه الأسواق العالمية في الشهر الماضي، فإن مؤشر دول مجلس التعاون، والذي يقيس أداء أكبر 40 شركة في المنطقة، وأكثرها سيولة، تفوق في الأداء، وسجل نمواً بنسبة 2.5%.وقال إن شركات الإمارات كانت الأفضل أداءً بمكاسب وصلت إلى 2.9%. من جهة أخرى لفت البيان إلى التراجع في أداء المؤشرات العالمية على خلفية الأوضاع المالية والاقتصادية في اليونان والصين.
# ...

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 59.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 24.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 76.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 9.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 13.0.1
#     Uninstalling websockets-13.0.1:
#       Successfully uninstalled websockets-13.0.1
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.13.2
#     Uninstalling tomlkit-0.13.2:
#       Successfully uninstalled tomlkit-0.13.2
# ...

# %%
import gradio as gr


iface = gr.Interface(
    fn=process_question,
    inputs="text",
    outputs=[
        gr.Textbox(label="Top3 Similar Articles"),
        gr.Textbox(label="Answer:")
    ],
    title="RAG Project",
    description="Enter your question."
)

iface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://ab0cf04ea1ae56b348.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ab0cf04ea1ae56b348.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ***Inferance***

# %%
# !pip install faiss-cpu
# !pip install langchain
# !pip install langchain_google_genai
# !pip install langchain_chroma
# !pip install sentence_transformers
# !pip install gradio

from langchain_core.output_parsers import StrOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import PromptTemplate
from langchain.vectorstores import Chroma

from tqdm import tqdm
from google.colab import files
from sentence_transformers import SentenceTransformer
from langchain_chroma import Chroma
from sentence_transformers import SentenceTransformer
import torch
import os
import os
import glob
import gradio as gr
import zipfile

# %%
class embedding:
    def __init__(self):
        self.model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2').to(device)

    def embed_documents(self, docs):
        embeddings = self.model.encode(docs, convert_to_tensor=True, device=device)
        return embeddings.cpu().numpy().tolist()

    def embed_query(self, query):
        embeddings = self.model.encode(query, convert_to_tensor=True, device=device)
        return embeddings.cpu().numpy().tolist()

embed_model2 = embedding()

# %%
from googledriver import download_folder

URL = "https://drive.google.com/drive/folders/1w7hUiuMAPZbMCMG_jGCfED88VmGoh2Pi?usp=sharing"

download_folder(URL, "/content/chroma_db")

# %%
# Load the Chroma vector database
vector_database_test2 = Chroma(
    embedding_function=embed_model2,
    persist_directory='chroma_db'
)
retreiver_test2 = vector_database_test2.as_retriever(search_type='similarity', search_kwargs={'k': 3})

# %%
def retrieve_articles(question):
    articles = [
        retreiver_test2.invoke(question)[0].page_content,
        retreiver_test2.invoke(question)[1].page_content,
        retreiver_test2.invoke(question)[2].page_content
    ]
    return articles

def get_answer(question):
    answer = rag_chain2.invoke(question)
    return answer

def process_question(question):
    articles = retrieve_articles(question)
    answer = get_answer(question)
    return articles, answer

# %%
GOOGLE_API_KEY = "AIzaSyDUbM4d5dN8fXevXjT4L5oRmv3i2r7ZvR0"



llm2 = ChatGoogleGenerativeAI(model="gemini-1.5-flash",google_api_key =GOOGLE_API_KEY ,temperature=0)

template = """
As a knowledgeable and context-aware Arabic AI assistant,
your role is to deliver accurate and thorough responses to customer inquiries.
Utilize the retrieved information from the knowledge base to craft a well-informed answer.

Question: {question}

Relevant Information:
{context}

Generate a clear and precise Arabic response using the provided context.
"""

prompt=PromptTemplate.from_template(template)
rag_chain2 = (
     {"context": context_chain,"question": RunnablePassthrough()}
     | prompt
     | llm2
     |StrOutputParser()
)

# %%
iface = gr.Interface(
    fn=process_question,
    inputs="text",
    outputs=[
        gr.Textbox(label="Top3 Similar Articles"),
        gr.Textbox(label="Answer:")
    ],
    title="RAG Project",
    description="Enter your question."
)

iface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://6910adb5e13edda3e6.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6910adb5e13edda3e6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
